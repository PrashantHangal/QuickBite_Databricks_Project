# %%
# %sql
CREATE CATALOG IF NOT EXISTS uc_quickbite;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS uc_quickbite.bronze_ingestion;
CREATE SCHEMA IF NOT EXISTS uc_quickbite.silver_transform;
CREATE SCHEMA IF NOT EXISTS uc_quickbite.gold_aggregate;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS uc_quickbite.default.qbVolume;
